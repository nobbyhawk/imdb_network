# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the csv file
movies = pd.read_csv("movie_metadata.csv")

# %%
# Print the column names
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# How many movies do we have?
movies.shape
# Out:
# (5043, 28)

# %%
# Preview of dataset
movies.head()

# Drop duplicated columns
movies = movies.drop_duplicates()

# Drop columns that we do not need
movies_short = movies.loc[:,['movie_title', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'imdb_score', 'genres']]

# Preview the new dataframe
movies_short.head()
# Out:
#                                          movie_title     actor_1_name  \
# 0                                            Avatar       CCH Pounder
# 1          Pirates of the Caribbean: At World's End       Johnny Depp
# 2                                           Spectre   Christoph Waltz
# 3                             The Dark Knight Rises         Tom Hardy
# 4  Star Wars: Episode VII - The Force Awakens    ...      Doug Walker
#
#        actor_2_name          actor_3_name  imdb_score  \
# 0  Joel David Moore             Wes Studi         7.9
# 1     Orlando Bloom        Jack Davenport         7.1
# 2      Rory Kinnear      Stephanie Sigman         6.8
# 3    Christian Bale  Joseph Gordon-Levitt         8.5
# 4        Rob Walker                   NaN         7.1
#
#                             genres
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary

# %%
def gephi(movies):
    movies = movies.loc[:,['actor_1_name', 'actor_2_name', 'actor_3_name', 'imdb_score']]
    movies = movies.replace(' ', '_', regex=True) # replace whitespace by underscore, since Gephi doesn't recognize spaces
    movies = movies.reset_index(drop=True) # reset indices
    return(movies)

# %%
actors = gephi(movies_short)
# Out:
#                  actor_1_name          actor_2_name          actor_3_name  \
# 0                 CCH_Pounder      Joel_David_Moore             Wes_Studi
# 1                 Johnny_Depp         Orlando_Bloom        Jack_Davenport
# 2             Christoph_Waltz          Rory_Kinnear      Stephanie_Sigman
# 3                   Tom_Hardy        Christian_Bale  Joseph_Gordon-Levitt
# 4                 Doug_Walker            Rob_Walker                   NaN
# 5                Daryl_Sabara       Samantha_Morton          Polly_Walker
# 6                J.K._Simmons          James_Franco         Kirsten_Dunst
# 7                Brad_Garrett          Donna_Murphy           M.C._Gainey
# 8             Chris_Hemsworth     Robert_Downey_Jr.    Scarlett_Johansson
# 9                Alan_Rickman      Daniel_Radcliffe          Rupert_Grint
# 10               Henry_Cavill          Lauren_Cohan        Alan_D._Purwin
# 11               Kevin_Spacey         Marlon_Brando        Frank_Langella
# 12         Giancarlo_Giannini       Mathieu_Amalric          Rory_Kinnear
# 13                Johnny_Depp         Orlando_Bloom        Jack_Davenport
# 14                Johnny_Depp           Ruth_Wilson         Tom_Wilkinson
# 15               Henry_Cavill    Christopher_Meloni          Harry_Lennix
# 16             Peter_Dinklage  Pierfrancesco_Favino        Damián_Alcázar
# 17            Chris_Hemsworth     Robert_Downey_Jr.    Scarlett_Johansson
# 18                Johnny_Depp           Sam_Claflin        Stephen_Graham
# 19                 Will_Smith     Michael_Stuhlbarg    Nicole_Scherzinger
# 20               Aidan_Turner            Adam_Brown         James_Nesbitt
# 21                 Emma_Stone       Andrew_Garfield           Chris_Zylka
# 22                  Mark_Addy          William_Hurt          Scott_Grimes
# 23               Aidan_Turner            Adam_Brown         James_Nesbitt
# 24            Christopher_Lee             Eva_Green  Kristin_Scott_Thomas
# 25                Naomi_Watts    Thomas_Kretschmann            Evan_Parke
# 26          Leonardo_DiCaprio          Kate_Winslet         Gloria_Stuart
# 27          Robert_Downey_Jr.    Scarlett_Johansson           Chris_Evans
# 28                Liam_Neeson   Alexander_Skarsgård        Tadanobu_Asano
# 29        Bryce_Dallas_Howard            Judy_Greer               Omar_Sy
# ...                       ...                   ...                   ...
# 4968                 Franky_G        Panchito_Gómez       Casper_Martinez
# 4969              Matt_Frewer    Katharine_Isabelle          Michael_Paré
# 4970           Tommy_Pallotta     Richard_Linklater         Jean_Caffeine
# 4971              Tjasa_Ferme          Mikaal_Bates           Damon_Owlia
# 4972           Kristen_Seavey         Suzi_Lorraine          Travis_Legge
# 4973           Shannen_Fields           Lisa_Arnold      Janet_Lee_Dapper
# 4974          Ashley_Tramonte       Brittany_Curran     Lindsay_MacDonald
# 4975            Robbie_Barnes       Alana_Kaniewski       Brandon_Landers
# 4976             Mark_Duplass         Katie_Aselton            Bari_Hyman
# 4977               Paul_Ogola         Olwenya_Maina        Mugambi_Nthiga
# 4978         Zoe_Lister-Jones         Heather_Burns    Ebon_Moss-Bachrach
# 4979              Sean_Whalen           Jason_Trost         Nick_Principe
# 4980                   Divine            Mink_Stole          Edith_Massey
# 4981            Maggie_Cheung        Béatrice_Dalle          Don_McKellar
# 4982  Fereshteh_Sadre_Orafaiy     Nargess_Mamizadeh      Mojgan_Faramarzi
# 4983        Patrick_O'Donnell         Michael_Parle      Emma_Eliza_Regan
# 4984             Kôji_Yakusho         Anna_Nakagawa                Denden
# 4985      Tatiana_Suarez-Pico        Michael_Cortez           Eric_Ambriz
# 4986            Julianna_Pitt            Joe_Coffey            John_Lucas
# 4987             Peter_Greene     Stanley_B._Herman           James_Noble
# 4988            Shane_Carruth        David_Sullivan          Casey_Gooden
# 4989              Ian_Gamazon       Edgar_Tancangco             Quynn_Ton
# 4990          Carlos_Gallardo       Peter_Marquardt        Consuelo_Gómez
# 4991           Richard_Jewell        John_Considine        Sara_Stepnicka
# 4992              Kerry_Bishé    Caitlin_FitzGerald       Daniella_Pineda
# 4993              Eric_Mabius         Daphne_Zuniga          Crystal_Lowe
# 4994              Natalie_Zea         Valorie_Curry         Sam_Underwood
# 4995              Eva_Boehnke         Maxwell_Moody        David_Chandler
# 4996                Alan_Ruck         Daniel_Henney           Eliza_Coupe
# 4997              John_August      Brian_Herzlinger              Jon_Gunn
#
#       imdb_score
# 0            7.9
# 1            7.1
# 2            6.8
# 3            8.5
# 4            7.1
# 5            6.6
# 6            6.2
# 7            7.8
# 8            7.5
# 9            7.5
# 10           6.9
# 11           6.1
# 12           6.7
# 13           7.3
# 14           6.5
# 15           7.2
# 16           6.6
# 17           8.1
# 18           6.7
# 19           6.8
# 20           7.5
# 21           7.0
# 22           6.7
# 23           7.9
# 24           6.1
# 25           7.2
# 26           7.7
# 27           8.2
# 28           5.9
# 29           7.0
# ...          ...
# 4968         7.0
# 4969         6.3
# 4970         7.1
# 4971         4.8
# 4972         3.3
# 4973         6.9
# 4974         4.6
# 4975         3.0
# 4976         6.6
# 4977         7.4
# 4978         6.2
# 4979         4.0
# 4980         6.1
# 4981         6.9
# 4982         7.5
# 4983         6.7
# 4984         7.4
# 4985         6.1
# 4986         5.4
# 4987         6.4
# 4988         7.0
# 4989         6.3
# 4990         6.9
# 4991         7.8
# 4992         6.4
# 4993         7.7
# 4994         7.5
# 4995         6.3
# 4996         6.3
# 4997         6.6
#
# [4998 rows x 4 columns]

# %%
# Print out the actor CSV
actors.to_csv("actors.csv", sep = ",", index = False, header = False)

# %%
# function to get unique values 
def unique(list1): 
  
    # intilize a null list 
    unique_list = [] 
      
    # traverse for all elements 
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x) 
    # return list 
    return(unique_list)

# %%
unique_list = unique(actors["actor_1_name"].append(actors["actor_2_name"]).append(actors["actor_3_name"]))
unique_list.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-5db701ced38c> in <module>()
#       1 unique_list = unique(actors["actor_1_name"].append(actors["actor_2_name"]).append(actors["actor_3_name"]))
# ----> 2 unique_list.sort()
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
df2 = pd.DataFrame(np.zeros((len(unique_list), len(unique_list))), columns=unique_list, index = unique_list)

# %%
df2.to_csv("test.csv", sep = ";", index = True, header = True)

# %%
for i in unique_list:
    for j in unique_list:
        if i != j:
            ratings = []
            
df2.iloc[0,0]
# Out:
# 0.0

# %%
# Out:
# True
